# %%
import pandas as pd
data_frame = pd.read_csv("data.csv", encoding='latin-1')
data_frame
# Out:
#        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18206.000000  18206.000000  18207.000000
# mean    9103.000000  214298.338606     25.122048     66.237449     71.307299
# std     5256.052511   29965.244204      4.670022      6.907059      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.head()
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
# 3           3  193080             De Gea  27.0
# 4           4  192985       K. De Bruyne  27.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
# 3  https://cdn.sofifa.org/flags/45.png     91.0         93
# ...

# %%
data_frame.head(3)
# Out:
#    Unnamed: 0      ID               Name   Age  \
# 0           0  158023           L. Messi  31.0
# 1           1   20801  Cristiano Ronaldo  33.0
# 2           2  190871          Neymar Jr  26.0
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png     94.0         94
# 1  https://cdn.sofifa.org/flags/38.png     94.0         94
# 2  https://cdn.sofifa.org/flags/54.png     92.0         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %%
data_frame.tail(3)
# Out:
#        Unnamed: 0      ID            Name   Age  \
# 18204       18204  241638       B. Worman  16.0
# 18205       18205  246268  D. Walker-Rice  17.0
# 18206       18206  246269       G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18204  https://cdn.sofifa.org/flags/14.png     47.0         67
# 18205  https://cdn.sofifa.org/flags/14.png     47.0         66
# 18206  https://cdn.sofifa.org/flags/14.png     46.0         66
#
#                    Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 18204  Cambridge United  ...      41.0    32.0           13.0           11.0
# 18205   Tranmere Rovers  ...      46.0    20.0           25.0           27.0
# ...

# %%
data_frame.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# ...

# %% [markdown]
# it return the mean of all columns

# %%
data_frame.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of        Unnamed: 0      ID                Name   Age  \
# 0               0  158023            L. Messi  31.0
# 1               1   20801   Cristiano Ronaldo  33.0
# 2               2  190871           Neymar Jr  26.0
# 3               3  193080              De Gea  27.0
# 4               4  192985        K. De Bruyne  27.0
# ...           ...     ...                 ...   ...
# 18202       18202  238813        J. Lundstram  19.0
# 18203       18203  243165  N. Christoffersson  19.0
# 18204       18204  241638           B. Worman  16.0
# 18205       18205  246268      D. Walker-Rice  17.0
# 18206       18206  246269           G. Nugent  16.0
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# ...

# %%
data_frame["Name"].head(5)
# Out:
# 0             L. Messi
# 1    Cristiano Ronaldo
# 2            Neymar Jr
# 3               De Gea
# 4         K. De Bruyne
# Name: Name, dtype: object

# %%
data_frame[data_frame["Age"]>40].head()
# Out:
#        Unnamed: 0      ID         Name   Age  \
# 1120         1120  156092    J. Villar  41.0
# 4228         4228    3665     B. Nivet  41.0
# 4741         4741  140029     O. Pérez  45.0
# 7225         7225  142998     C. Muñoz  41.0
# 10545       10545  140183  S. Narazaki  42.0
#
#                                                 Photo Nationality  \
# 1120   https://cdn.sofifa.org/players/4/19/156092.png    Paraguay
# 4228     https://cdn.sofifa.org/players/4/19/3665.png      France
# 4741   https://cdn.sofifa.org/players/4/19/140029.png      Mexico
# 7225   https://cdn.sofifa.org/players/4/19/142998.png   Argentina
# 10545  https://cdn.sofifa.org/players/4/19/140183.png       Japan
#
#                                        Flag  Overall  Potential  \
# 1120    https://cdn.sofifa.org/flags/58.png     77.0         77
# 4228    https://cdn.sofifa.org/flags/18.png     71.0         71
# 4741    https://cdn.sofifa.org/flags/83.png     71.0         71
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])
df1
# Out:
#                      Name   Wage    Value
# 0                L. Messi  565K  110.5M
# 1       Cristiano Ronaldo  405K     77M
# 2               Neymar Jr  290K  118.5M
# 3                  De Gea  260K     72M
# 4            K. De Bruyne  355K    102M
# ...                   ...    ...      ...
# 18202        J. Lundstram    1K     60K
# 18203  N. Christoffersson    1K     60K
# 18204           B. Worman    1K     60K
# 18205      D. Walker-Rice    1K     60K
# 18206           G. Nugent    1K     60K
#
# [18207 rows x 3 columns]

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0

wage = df1['Wage'].replace('[\,]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\,]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference']=df1['Value']-df1['Wage']
df1
# Out:
#                      Name      Wage        Value   difference
# 0                L. Messi  565000.0  110500000.0  109935000.0
# 1       Cristiano Ronaldo  405000.0   77000000.0   76595000.0
# 2               Neymar Jr  290000.0  118500000.0  118210000.0
# 3                  De Gea  260000.0   72000000.0   71740000.0
# 4            K. De Bruyne  355000.0  102000000.0  101645000.0
# ...                   ...       ...          ...          ...
# 18202        J. Lundstram    1000.0      60000.0      59000.0
# 18203  N. Christoffersson    1000.0      60000.0      59000.0
# 18204           B. Worman    1000.0      60000.0      59000.0
# 18205      D. Walker-Rice    1000.0      60000.0      59000.0
# 18206           G. Nugent    1000.0      60000.0      59000.0
#
# [18207 rows x 4 columns]

# %%
df1.sort_values('difference', ascending=False)
# Out:
#                Name      Wage        Value   difference
# 2         Neymar Jr  290000.0  118500000.0  118210000.0
# 0          L. Messi  565000.0  110500000.0  109935000.0
# 4      K. De Bruyne  355000.0  102000000.0  101645000.0
# 5         E. Hazard  340000.0   93000000.0   92660000.0
# 15        P. Dybala  205000.0   89000000.0   88795000.0
# ...             ...       ...          ...          ...
# 17752   S. Phillips    1000.0          0.0      -1000.0
# 12192  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    S. Nakamura    4000.0          0.0      -4000.0
# 4228       B. Nivet    5000.0          0.0      -5000.0
# 864          Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool
TOOLTIPS = HoverTool(tooltips=[
    ('index', '$index'),
    ('(Wage,Value)', '(@Wage, @Value)'),
    ('Name', '@Name')]
                    )
p = figure(title="Soccer 2019", x_axis_label='Wage', y_axis_label='Value', outer_width=700, outer_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
